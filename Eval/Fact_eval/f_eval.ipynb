# %%
import json

# %%
with open("expert_eval_samples.json", "r") as f:
    data = json.load(f)

# %%
data[0].keys()
# Out:
# dict_keys(['CNR', 'case_details', 'outcome', 'statutes_info', 'reason_court', 'reason_ft', 'reason_baseline', 'baseline_results', 'ft_results'])
